# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn
import github as gh
import scipy.spatial.distance as dist
import scipy.cluster.hierarchy as hier

# %% [markdown]
# # Analysis of repositories in terms of how geography, temporality and networks create Github as a platform
#
# The question I am after here is: **how much can we tell about Github as a hub or platform from the work that Github team/staff do on it?**

# %% [markdown]
# ## Load the data

# %%
#Load team description: I added the countries in manually, so load this to see team members (including )
team_df = pd.read_csv('data/github_team_with_countries.csv', sep='\t')

# Load team repository descriptions
all_team_repos = pd.read_csv('data/github_team_repos.csv', sep='\t')

# Load general event descriptions
all_events = pd.read_csv('data/event_counts_top100k.csv', sep = '\t')

# %% [markdown]
# ## Claims about decentralized work
#
# Github claims to be about remote working from many places

# %%
country_counts = team_df.country.value_counts()
print 'There are {} different countries in the team'.format(country_counts.shape)
fig1 = plt.figure(figsize = (12,10))
fig1.add_subplot(121)
country_counts.plot(kind='barh',title = 'Locations of Github team (countries)')
fig1.add_subplot(122)
city_counts = team_df.location.value_counts()
sp = city_counts.plot(kind='barh', title = 'Locations of Github team (cities)')
# Out:
# There are (14,) different countries in the team

# %%
fig1.savefig('plots/locations.svg')
fig1.savefig('plots/locations.png')

# %%
team_df[['name', 'login', 'id', 'created_at', 'followers', 'location']].sort([ 'followers', 'created_at'], ascending=False).head(20)
# team_df.followers.hist(bins=100)
# Out:
#                    name         login       id            created_at  \
# 233  Tom Preston-Werner       mojombo        1  2007-10-20T05:24:19Z
# 0       Chris Wanstrath       defunkt        2  2007-10-20T05:24:19Z
# 2          Scott Chacon       schacon       70  2008-01-27T17:19:28Z
# 1              PJ Hyett       pjhyett        3  2008-01-07T17:54:22Z
# 3                Tekkub        tekkub      706  2008-02-23T21:14:45Z
# 97            Mark Otto           mdo    98681  2009-06-25T02:06:14Z
# 136        Jessica Lord         jlord  1305617  2012-01-05T03:24:52Z
# 6           Zach Holman        holman     2723  2008-03-10T16:32:37Z
# 153  Charlie Somerville   charliesome   179065  2010-01-09T14:49:23Z
# 7     risk danger olson  technoweenie       21  2008-01-14T04:33:35Z
# 161         Mu-An Chiou          muan  1153134  2011-10-26T12:53:14Z
# 5          Ryan Tomayko      rtomayko      404  2008-02-19T03:30:53Z
# 221     Mislav Marohnić        mislav      887  2008-02-25T20:18:33Z
# 121          Ben Balter     benbalter   282759  2010-05-20T20:38:33Z
# 20          Joshua Peek          josh      137  2008-02-03T22:05:54Z
# 16           Aman Gupta          tmm1     2567  2008-03-08T02:10:31Z
# 40           Phil Haack       Haacked    19977  2008-08-08T03:36:05Z
# 36       John Nunemaker    jnunemaker      235  2008-02-13T18:00:42Z
# 18        Kevin Sawicki  kevinsawicki   671378  2011-03-15T16:46:18Z
# 4            Kyle Neath        kneath     1354  2008-02-28T00:48:15Z
#
#      followers       location
# 233      17169  san francisco
# 0        13447  san francisco
# 2         9833  san francisco
# 1         8034  san francisco
# 3         4809         denver
# 97        4228  san francisco
# 136       3475        oakland
# 6         3356  san francisco
# 153       2512      melbourne
# 7         2028     rapid city
# 161       1808         taipei
# 5         1625  san francisco
# 221       1306         europe
# 121       1298     washington
# 20        1268        chicago
# 16        1203  san francisco
# 40        1188       bellevue
# 36        1143     south bend
# 18         941   redwood city
# 4          927  san francisco
#
# [20 rows x 6 columns]

# %% [markdown]
# ## Weighting the events
#
# The Github team has produced around 350k events since early 2012 working on 17000 repositories.

# %%
# to weight the events 

evts = all_team_repos.groupby('type')['event_count'].sum()


print 'Roughly {} events have been performed by the Github team on {} repositories'.format(evts.sum(), +
               len(all_team_repos.repository_url.unique()))

print("The repo events in descending order")

evts = evts.order(ascending=False)
print evts
# plot the events in barchart
# Out:
# Roughly 351371.0 events have been performed by the Github team on 17001 repositories
# The repo events in descending order
# type
# PushEvent                        112284
# IssueCommentEvent                 84377
# PullRequestEvent                  36179
# CreateEvent                       31105
# IssuesEvent                       26041
# PullRequestReviewCommentEvent     16415
# WatchEvent                        13631
# DeleteEvent                        8033
# FollowEvent                        5400
# ForkEvent                          5290
# CommitCommentEvent                 4548
# GistEvent                          3063
# GollumEvent                        2264
# ReleaseEvent                        911
# MemberEvent                         902
# PublicEvent                         572
# DownloadEvent                       350
# ForkApplyEvent                        6
# Name: event_count, dtype: float64

# %%
fig1a = plt.figure(figsize=(10,6))
colrs = 'rgbkymc' 
y_pos = np.arange(evts.shape[0])
plt.barh(y_pos, evts)
plt.yticks(y_pos, evts.index)

plt.title('Event types on Github team public repositories')

# %%
sp1a = evts.plot(kind='barh', title = 'Event counts for Github team', colors=colrs)

# %%
fig1a.savefig( 'plots/events_github_team.svg')
fig1a.savefig( 'plots/events_github_team.png')

# %%
# repo count by URLs
repos_by_event_count = all_team_repos.groupby('repository_url')['event_count'].sum().order(ascending=False)
fig2 = plt.figure(figsize=(14,10))
fig2.add_subplot(121)

sp1 = repos_by_event_count[:50].plot(kind='barh', title = 'Repositories worked on by Github team (since 2012)', color='r')
sp1.set_xlabel('Number of events')
sp1.set_ylabel('Repository url')
## to focus on repo names
repo_name_by_event_count = all_team_repos.groupby('repository_name')['event_count'].sum().order(ascending=False)
fig2.add_subplot(122)
sp2 = repo_name_by_event_count[:50].plot(kind='barh', 
                                        title = 'Unique Repositories worked on by Github team (since 2012)', color = 'g')
sp2.set_xlabel('Number of events')
sp2.set_ylabel('Repository name')

# %%
fig2.savefig('plots/github_team_repos_by_event_count.svg')
fig2.savefig('plots/github_team_repos_by_event_count.png')

# %% [markdown]
# ## Collaborative work on repos
#
# 2 main questions here:
#
# 1. which actors work together (and does this relate to geography)?
# 2. which repositories link different actors together?
#
#
# Need to transform data so that it has a row for each actor and columns for each repository name, with counts of events on each repo

# %%
# choose top 100 repos by total event count

top_repos = repos_by_event_count.index[:300]
top_repo_events = all_team_repos.ix[all_team_repos['repository_url'].isin(top_repos.values.tolist())]

# %%
top_repo_events.ix[:,[1,3,4,2]].head(20)
# Out:
#                         actor                                  repository_url  \
# repository_name
# gitignore             defunkt             https://github.com/github/gitignore
# gitignore             defunkt             https://github.com/github/gitignore
# dotjs                 defunkt                https://github.com/defunkt/dotjs
# dotjs                 defunkt                https://github.com/defunkt/dotjs
# gitignore             defunkt             https://github.com/github/gitignore
# dotjs                 defunkt                https://github.com/defunkt/dotjs
# dotjs                 defunkt                https://github.com/defunkt/dotjs
# jquery-pjax           defunkt          https://github.com/defunkt/jquery-pjax
# jquery-pjax           defunkt          https://github.com/defunkt/jquery-pjax
# jquery-pjax           defunkt          https://github.com/defunkt/jquery-pjax
# jquery-pjax           defunkt          https://github.com/defunkt/jquery-pjax
# dotjs                 defunkt                https://github.com/defunkt/dotjs
# homebrew              defunkt                https://github.com/mxcl/homebrew
# jquery-pjax           defunkt          https://github.com/defunkt/jquery-pjax
# hub                   defunkt                  https://github.com/defunkt/hub
# json_builder          defunkt          https://github.com/dewski/json_builder
# homebrew              defunkt                https://github.com/mxcl/homebrew
# html-pipeline         defunkt            https://github.com/jch/html-pipeline
# jquery-pjax           defunkt          https://github.com/defunkt/jquery-pjax
# developer.github.com  defunkt  https://github.com/github/developer.github.com
#
#                                                type  event_count
# repository_name
# gitignore                          PullRequestEvent          135
# gitignore                                 PushEvent           99
# dotjs                             IssueCommentEvent           77
# dotjs                                     PushEvent           54
# gitignore                         IssueCommentEvent           54
# dotjs                                   IssuesEvent           52
# dotjs                              PullRequestEvent           41
# jquery-pjax                       IssueCommentEvent           23
# jquery-pjax                        PullRequestEvent           17
# jquery-pjax                               PushEvent           13
# jquery-pjax                             IssuesEvent            7
# dotjs                                   CreateEvent            7
# homebrew                          IssueCommentEvent            6
# jquery-pjax                             MemberEvent            4
# hub                               IssueCommentEvent            3
# json_builder                             WatchEvent            3
# homebrew                           PullRequestEvent            3
# html-pipeline         PullRequestReviewCommentEvent            3
# jquery-pjax                              WatchEvent            3
# developer.github.com                      PushEvent            2
#
# [20 rows x 4 columns]

# %%
#sum all the events for each actor for each repository
actor_top_repos = top_repo_events.groupby(['actor', 'repository_name'])['event_count'].sum().reset_index()
actor_top_repos.head()
# Out:
#    actor       repository_name  event_count
# 0  Caged                  atom            1
# 1  Caged                d3-tip          266
# 2  Caged  developer.github.com            5
# 3  Caged                gemoji            1
# 4  Caged         hubot-scripts            3
#
# [5 rows x 3 columns]

# %%
# put actor and repos into wide format
actor_repos_df = actor_top_repos.pivot(index='actor', columns = 'repository_name', values = 'event_count')
actor_repos_df.fillna(0, inplace=True)
actor_repos_df.to_csv('data/actor_repos_top_wide.csv', sep='\t')
actor_repos_df.shape
# Out:
# (194, 264)

# %%
#to get event counts for each actor across all repos
actor_repos_df.sum(axis=1).order(ascending=False)[:30]
# Out:
# actor
# mikemcquaid          18976
# mdo                  14563
# jspahrsummers        14040
# gjtorikian            7594
# mislav                6776
# kevinsawicki          6129
# joshaber              6061
# benbalter             5620
# shiftkey              5489
# arrbee                4790
# dbussink              4509
# piki                  4429
# Haacked               4325
# josh                  4199
# vmg                   4062
# charliesome           3825
# atmos                 3822
# alindeman             3726
# andrew                3506
# matthewmccullough     3475
# pengwynn              3340
# technoweenie          3329
# holman                2952
# technicalpickles      2749
# afeld                 2715
# peff                  2669
# paulcbetts            2448
# raganwald             2364
# aroben                2340
# bkeepers              2323
# dtype: float64

# %%
# calculate distance matrix between actors
actor_distances = dist.pdist(actor_repos_df.values,'canberra')
dist.squareform(actor_distances)[10]
# Out:
# array([ 12.        ,   6.        ,   0.5       ,   2.        ,
#         26.        ,   2.        ,   4.        ,   7.66666667,
#         10.        ,  12.        ,   0.        ,  48.        ,
#         16.        ,  33.8       ,   9.        ,   3.        ,
#          4.        ,  22.        ,  12.        ,  12.        ,
#         26.75      ,  12.        ,  11.        ,  25.99369085,
#          5.        ,   5.        ,  32.        ,  14.        ,
#          2.        ,  14.75      ,  27.        ,   4.        ,
#         10.        ,   7.        ,  14.        ,  19.        ,
#         17.5       ,  19.        ,  15.        ,  28.        ,
#         11.        ,   5.        ,   5.        ,  33.        ,
#          7.        ,   4.        ,   8.        ,  16.        ,
#          2.        ,  11.        ,  20.        ,  13.33333333,
#          8.        ,  22.        ,   7.        ,  10.        ,
#          3.        ,   6.        ,   3.        ,   6.        ,
#          2.        ,   5.        ,  12.33333333,   9.        ,
#          3.        ,  35.        ,   9.        ,   8.        ,
#         21.        ,   6.        ,  25.        ,  10.        ,
#          5.        ,   2.33333333,   4.        ,   6.        ,
#          9.        ,  20.33333333,  15.        ,  10.        ,
#          2.        ,   4.        ,   2.        ,   3.        ,
#          5.        ,  33.33333333,  10.        ,   5.        ,
#          8.8       ,   6.        ,  11.        ,  14.        ,
#          3.        ,  26.        ,  15.75      ,  21.33333333,
#         10.        ,  35.        ,  20.        ,  16.        ,
#          4.        ,  29.        ,   2.        ,   6.        ,
#         11.        ,   4.        ,   2.        ,  10.        ,
#         19.6       ,  33.        ,   9.        ,   2.        ,
#         16.        ,   4.        ,   4.        ,   2.        ,
#          9.        ,   8.        ,   6.33333333,  22.33333333,
#         34.        ,  12.        ,  11.        ,  12.        ,
#         14.        ,   2.        ,   6.        ,  10.        ,
#          9.        ,  35.        ,   7.        ,  15.        ,
#         18.        ,   3.        ,   5.33333333,  17.        ,
#          2.        ,   2.        ,   6.        ,   8.        ,
#         21.        ,   6.        ,  23.        ,  11.        ,
#         35.        ,   5.        ,   7.        ,   3.        ,
#         18.        ,   9.        ,   4.        ,  11.        ,
#          2.        ,  23.        ,  23.        ,   6.        ,
#          4.        ,  18.        ,   5.        ,  15.        ,
#         17.        ,   2.        ,   3.        ,   2.        ,
#         15.        ,   7.        ,  13.        ,   5.        ,
#          6.        ,  27.        ,   1.5       ,  23.        ,
#          2.        ,   2.        ,   7.        ,  14.        ,
#          7.        ,  13.        ,   4.        ,   4.        ,
#          4.        ,  14.        ,   9.99753086,  22.        ,
#         23.        ,  14.        ,   4.        ,  20.        ,
#         21.33333333,  10.        ,  19.        ,  15.        ,
#         18.6       ,   8.        ])

# %%
actor_distances[:10]
# Out:
# array([ 14.6       ,  12.        ,  12.        ,  33.60576923,
#         12.        ,  12.5       ,  17.25      ,  18.25      ,
#         16.83333333,  12.        ])

# %%
fig3 = plt.figure(figsize=(12,20))
link_matrix = hier.linkage(actor_distances, method='average')
# hier.fcluster(link_matrix)

dendro = hier.dendrogram(link_matrix, orientation='right',labels = actor_repos_df.index.values)

# %%
# to look at actor-actor neighbours more directly
actor_actor_df = actor_repos_df.dot(actor_repos_df.transpose())
actor_actor_df.fillna(0, inplace=True)
actor_actor_df.head()
actor_actor = actor_actor_df.values
np.fill_diagonal(actor_actor, 0)
actor_actor_df_zeroed = pd.DataFrame(actor_actor, columns = actor_actor_df.columns, index = actor_actor_df.index)
actor_actor_df_zeroed.head()
actor_actor_df_zeroed.to_csv('data/actor_actor.csv', sep='\t')

# %%
actor_actor_df_zeroed.index.name = 'actor1'
# actor_actor_df_zeroed.columns.name = 'actor2'

# %%
#stack the actor-actor relations
actor_actor_stacked = actor_actor_df_zeroed.stack()

# %%
actor_actor_stacked_df = pd.DataFrame(actor_actor_stacked)
actor_actor_stacked_df.head()
# Out:
#                         0
# actor1 actor1
# Caged  Caged            0
#        ChrisLundquist  36
#        ElizabethN       0
#        Foggybtmgirl     0
#        Haacked         67
#
# [5 rows x 1 columns]

# %%
# to look at repo-repo connections more directly
repo_repo_df = actor_repos_df.transpose().dot(actor_repos_df)
repo_repo_df.fillna( 0, inplace=True)
repo_repo_df.head()
# Out:
# repository_name  24pullrequests  Akavache  Archimedes  DownmarkerWPF  FRISCjs  \
# repository_name
# 24pullrequests          2547221         0           0              0        0
# Akavache                      0    184039         504          39468        0
# Archimedes                    0       504       32364              0        0
# DownmarkerWPF                 0     39468           0        1430416        0
# FRISCjs                       0         0           0              0    81225
#
# repository_name  Freezer  Hammer  JBDeviceOwner  LaHermosaVida  Lagrangian  \
# repository_name
# 24pullrequests         0       0              0              0           0
# Akavache               0       0              0              0           3
# Archimedes         10584    5140              0              0        2448
# DownmarkerWPF          0       0              0              0           0
# FRISCjs                0       0              0              0           0
#
# repository_name  MMMarkdown  MahApps.Metro  Mantle  ModernHttpClient  \
# repository_name
# 24pullrequests            0              0       0                 0
# Akavache                  3          31911    3666            121600
# Archimedes              224              0  212258                 0
# DownmarkerWPF             0        1156532       0                 0
# FRISCjs                   0              0       0                 0
#
# repository_name  ObjectiveHaskell  RXCollections  ReactiveCocoa  \
# repository_name
# 24pullrequests                  0              0           4788
# Akavache                      768              0          26006
# Archimedes                  43124           1796        1174012
# DownmarkerWPF                   0              0              0
# FRISCjs                         0              0              0
#
# repository_name  ReactiveCocoaLayout  ReactiveUI  Rebel
# repository_name
# 24pullrequests                     0           0      0 ...
# Akavache                        1494      525812   1188 ...
# Archimedes                    101482         742  72638 ...
# DownmarkerWPF                      0       26312      0 ...
# FRISCjs                            0           0      0 ...
#
# [5 rows x 264 columns]

# %%
repo_repo = repo_repo_df.values
np.fill_diagonal(repo_repo, 0)
repo_repo_df_zeroed = pd.DataFrame(repo_repo, columns = repo_repo_df.columns, index = repo_repo_df.index)
repo_repo_df_zeroed.head()
repo_repo_df_zeroed.to_csv('data/repo_repo.csv', sep='\t')

# %% [markdown]
# ## Events might be distributed differently for different members of the team

# %%
all_team_repos.columns
all_team_repos.head()
# Out:
#    Unnamed: 0    actor  event_count                       repository_url  \
# 0           0  defunkt          135  https://github.com/github/gitignore
# 1           1  defunkt           99  https://github.com/github/gitignore
# 2           2  defunkt           77     https://github.com/defunkt/dotjs
# 3           3  defunkt           54     https://github.com/defunkt/dotjs
# 4           4  defunkt           54  https://github.com/github/gitignore
#
#                 type
# 0   PullRequestEvent
# 1          PushEvent
# 2  IssueCommentEvent
# 3          PushEvent
# 4  IssueCommentEvent
#
# [5 rows x 5 columns]

# %%
events_by_team = all_team_repos.groupby(['type', 'actor'])['event_count'].sum()

# %%
events_by_team['PullRequestEvent'].order(ascending=False).head()
# Out:
# actor
# mikemcquaid      1882
# mdo              1797
# jspahrsummers    1681
# gjtorikian       1256
# vmg              1168
# Name: event_count, dtype: float64

# %%
events_by_team['PushEvent'].head()
# Out:
# actor
# Caged             296
# ChrisLundquist    452
# Coecoe              5
# ElizabethN          7
# Foggybtmgirl        9
# Name: event_count, dtype: float64

# %%
ct = pd.crosstab(all_team_repos.actor, all_team_repos.repository_name)
ct.shape
# Out:
# (226, 12868)

# %%
evt_df.head(30)
evt_df['event_count_log'] = np.log10(evt_df.event_count.values)
evt_df.event_count_log.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-411-993a4ae2871b> in <module>()
# ----> 1 evt_df.head(30)
#       2 evt_df['event_count_log'] = np.log10(evt_df.event_count.values)
#       3 evt_df.event_count_log.plot()
#
# NameError: name 'evt_df' is not defined
